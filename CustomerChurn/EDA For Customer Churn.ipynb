# %%
import os
os.chdir("C:\\Users\\SAI\\Desktop\\sai\\Handson")
os.getcwd()
# Out:
# 'C:\\Users\\SAI\\Desktop\\sai\\Handson'

# %%
import pandas as pd
dfCustChurn = pd.read_csv("CustomerChurn.csv")

# %%
dfCustChurn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
dfCustChurn.shape
# Out:
# (7043, 21)

# %%
dfCustChurn.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
dfCustChurn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
dfCustChurn.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
dfCustChurn.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
dfCustChurn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
import numpy as np
dfCustChurn['TotalCharges'] = dfCustChurn['TotalCharges'].replace(r'^\s*$',np.nan,regex = True)

# %%
dfCustChurn['TotalCharges'].isna().sum()
# Out:
# 11

# %%
dfCustChurn['TotalCharges'] = dfCustChurn['TotalCharges'].fillna(0)

# %%
dfCustChurn['TotalCharges'] = dfCustChurn['TotalCharges'].astype(float)

# %%
dfCustChurn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
dfCustChurn['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
dfCustChurn['SeniorCitizen']= dfCustChurn['SeniorCitizen'].replace(1,'YES').replace(0,'NO')

# %%
dfCustChurn['SeniorCitizen'].value_counts()
# Out:
# NO     5901
# YES    1142
# Name: SeniorCitizen, dtype: int64

# %%
import seaborn as sns

sns.countplot(x = 'SeniorCitizen', hue = 'Churn',data = dfCustChurn)

# %%
dfCustChurn['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
dfCustChurn['gender']= dfCustChurn['gender'].replace('Female',1).replace('Male',0)

# %%
dfCustChurn['gender'].value_counts()
# Out:
# 0    3555
# 1    3488
# Name: gender, dtype: int64

# %%
sns.countplot(x = 'gender', hue = 'Churn',data = dfCustChurn)

# %%
dfCustChurn['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
sns.countplot(x= 'Partner',hue = 'Churn',data = dfCustChurn)

# %%
dfCustChurn['TechSupport'].value_counts()
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
sns.countplot(x = 'TechSupport', hue = 'Churn', data = dfCustChurn)

# %%
dfCustChurn['gender'] = dfCustChurn['gender'].astype(object)

# %%
df_num = dfCustChurn.select_dtypes(include = ['float64','int64'])

# %%
df_num
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0          1           29.85         29.85
# 1         34           56.95       1889.50
# 2          2           53.85        108.15
# 3         45           42.30       1840.75
# 4          2           70.70        151.65
# 5          8           99.65        820.50
# 6         22           89.10       1949.40
# 7         10           29.75        301.90
# 8         28          104.80       3046.05
# 9         62           56.15       3487.95
# 10        13           49.95        587.45
# 11        16           18.95        326.80
# 12        58          100.35       5681.10
# 13        49          103.70       5036.30
# 14        25          105.50       2686.05
# 15        69          113.25       7895.15
# 16        52           20.65       1022.95
# 17        71          106.70       7382.25
# 18        10           55.20        528.35
# 19        21           90.05       1862.90
# 20         1           39.65         39.65
# ...

# %%
df_cat = dfCustChurn.select_dtypes(include = ['object'])

# %%
df_cat
# Out:
#       customerID gender SeniorCitizen Partner Dependents PhoneService  \
# 0     7590-VHVEG      1            NO     Yes         No           No
# 1     5575-GNVDE      0            NO      No         No          Yes
# 2     3668-QPYBK      0            NO      No         No          Yes
# 3     7795-CFOCW      0            NO      No         No           No
# 4     9237-HQITU      1            NO      No         No          Yes
# 5     9305-CDSKC      1            NO      No         No          Yes
# 6     1452-KIOVK      0            NO      No        Yes          Yes
# 7     6713-OKOMC      1            NO      No         No           No
# 8     7892-POOKP      1            NO     Yes         No          Yes
# 9     6388-TABGU      0            NO      No        Yes          Yes
# 10    9763-GRSKD      0            NO     Yes        Yes          Yes
# 11    7469-LKBCI      0            NO      No         No          Yes
# ...

# %%
dfCustChurn = dfCustChurn.drop('customerID',axis =1)

# %%
dfCustChurn.corr()
# Out:
#                   tenure  MonthlyCharges  TotalCharges
# tenure          1.000000        0.247900      0.826178
# MonthlyCharges  0.247900        1.000000      0.651174
# TotalCharges    0.826178        0.651174      1.000000

# %%
import seaborn
from matplotlib import pyplot as plt

fig,ax = plt.subplots(figsize=(10,10))
corr_df=df_num.corr(method = 'pearson')
mask = np.zeros_like(corr_df)
mask[np.triu_indices_from(mask)]=True
seaborn.heatmap(corr_df,cmap = 'RdYlGn',vmax= 1.0,vmin = -1.0, mask = mask, linewidth=2.5)
plt.yticks(rotation = 0)
plt.xticks(rotation = 90)
plt.show()

# %%
#dfCustChurn = dfCustChurn.drop('TotalCharges',axis =1)
